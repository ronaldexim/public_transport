# %% [markdown]
# <a href="https://colab.research.google.com/github/ronaldexim/public_transport/blob/master/public_transport_meeting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade tables                                                              # potrzebne do wczytania zawartości  plików hdf5 do colaba
# Out:
# Collecting tables
#   Downloading https://files.pythonhosted.org/packages/ed/c3/8fd9e3bb21872f9d69eb93b3014c86479864cca94e625fd03713ccacec80/tables-3.6.1-cp36-cp36m-manylinux1_x86_64.whl (4.3MB)
#      |████████████████████████████████| 4.3MB 2.8MB/s
# Requirement already satisfied, skipping upgrade: numexpr>=2.6.2 in /usr/local/lib/python3.6/dist-packages (from tables) (2.7.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.9.3 in /usr/local/lib/python3.6/dist-packages (from tables) (1.18.1)
# Installing collected packages: tables
#   Found existing installation: tables 3.4.4
#     Uninstalling tables-3.4.4:
#       Successfully uninstalled tables-3.4.4
# Successfully installed tables-3.6.1

# %% [markdown]
# ### Należy pobrać udostępnioną zawartość do katalogu na swoim Google Drive.
# ### public_transport.7z to wersja spakowana plików z danymi.
# ### Następnie łączymy Colaba z własnym Google Drive - ikonka katalogu po lewej stronie i "Mount Drive".
# ### Ścieżkę w następnej komórce należy dopasować to katalogu gdzie wgrano pliki.

# %%
cd "/content/drive/My Drive/public_transport"
# Out:
# /content/drive/My Drive/public_transport

# %%
import pandas as pd
import numpy as np
import pickle
import urllib.request, json
import datetime
import geopy.distance
from tqdm import tqdm

apikey = ''

# %%
stops_df = pd.read_hdf('public_transport_warsaw.h5', key='stops_df_4', mode='r')
lines_df = pd.read_hdf('public_transport_warsaw.h5', key='lines_df', mode='r')
schedule_df = pd.read_hdf('public_transport_warsaw2.h5', key='schedule_df_2', mode='r')
GPS_df = pd.read_hdf('public_transport_warsaw3.h5', key='GPS_df_1', mode='r')
print(stops_df.shape, lines_df.shape, schedule_df.shape, GPS_df.shape)
# Out:
# (7727, 19) (345, 3) (918719, 13) (1160129, 13)

# %%
GPS_df.dtypes
# Out:
# Lines                    object
# VehicleNumber            object
# Brigade                  object
# Time             datetime64[ns]
# Lon                     float64
# Lat                     float64
# res_type                 object
# qTime            datetime64[ns]
# d_time                    int64
# d_dist                  float64
# coord                    object
# uniqID                   object
# vehID                    object
# dtype: object

# %%
GPS_df.tail()
# Out:
#         Lines VehicleNumber  ...                         uniqID      vehID
# 1160124    14          3824  ...  14_3824_3_2020-02-12 10:54:39  14_3824_3
# 1160125    13          3827  ...  13_3827_1_2020-02-12 10:54:40  13_3827_1
# 1160126     6          3828  ...  6_3828_10_2020-02-12 10:54:41  6_3828_10
# 1160127     6          3829  ...   6_3829_9_2020-02-12 10:54:41   6_3829_9
# 1160128     6          3830  ...   6_3830_5_2020-02-12 10:54:42   6_3830_5
#
# [5 rows x 13 columns]

# %%
stop_coords = stops_df[stops_df.actual].set_index('id_nu')[['coord']].to_dict('dict')['coord']

# %%
# klucz (linia, brygada), zawiera listy z kolejnymi przystankami i planowanymi godzinami przyjazdu, czas i odległość od początku trasy

with open('schedule_dict.pickle', 'rb') as fp:
    schedule_dict = pickle.load(fp)

# %%
schedule_dict[('122', '4')]
# Out:
# [['5050_08', '05:41:00', 'Gwiaździsta', 'TP-GWI', 0, 0.0, 0.0],
#  ['5050_02', '05:42:00', 'Gwiaździsta', 'TP-GWI', 0, 60.0, 0.2326],
#  ['5051_02', '05:43:00', 'Gwiaździsta', 'TP-GWI', 0, 120.0, 0.51314],
#  ['5052_02', '05:44:00', 'Gwiaździsta', 'TP-GWI', 0, 180.0, 1.08088],
#  ['5053_02', '05:45:00', 'Gwiaździsta', 'TP-GWI', 0, 240.0, 1.6191],
#  ['5163_02', '05:45:00', 'Gwiaździsta', 'TP-GWI', 0, 240.0, 1.93824],
#  ['5054_02', '05:46:00', 'Gwiaździsta', 'TP-GWI', 0, 300.0, 2.65051],
#  ['5055_07', '05:47:00', 'Gwiaździsta', 'TP-GWI', 0, 360.0, 2.88631],
#  ['5110_01', '05:48:00', 'Gwiaździsta', 'TP-GWI', 0, 420.0, 3.40359],
#  ['5063_03', '05:50:00', 'Gwiaździsta', 'TP-GWI', 0, 540.0, 4.12568],
#  ['5106_01', '05:52:00', 'Gwiaździsta', 'TP-GWI', 0, 660.0, 4.65462],
#  ['5107_01', '05:53:00', 'Gwiaździsta', 'TP-GWI', 0, 720.0, 5.06485],
#  ['5064_07', '05:55:00', 'Gwiaździsta', 'TP-GWI', 0, 840.0, 5.72204],
#  ['5102_01', '05:56:00', 'Gwiaździsta', 'TP-GWI', 0, 900.0, 6.31435],
#  ['5062_01', '05:58:00', 'Gwiaździsta', 'TP-GWI', 0, 1020.0, 6.99106],
#  ['5065_01', '05:59:00', 'Gwiaździsta', 'TP-GWI', 0, 1080.0, 7.63714],
#  ['6047_03', '06:00:00', 'Gwiaździsta', 'TP-GWI', 0, 1140.0, 7.87316],
#  ['6132_01', '06:02:00', 'Gwiaździsta', 'TP-GWI', 0, 1260.0, 8.47429],
#  ['6131_01', '06:03:00', 'Gwiaździsta', 'TP-GWI', 0, 1320.0, 8.80097],
#  ['6155_01', '06:04:00', 'Gwiaździsta', 'TP-GWI', 0, 1380.0, 9.06434],
#  ['6129_01', '06:06:00', 'Gwiaździsta', 'TP-GWI', 0, 1500.0, 9.77458],
#  ['6093_01', '06:07:00', 'Gwiaździsta', 'TP-GWI', 0, 1560.0, 10.06012],
#  ['6091_04', '06:08:00', 'Gwiaździsta', 'TP-GWI', 0, 1620.0, 10.38083],
#  ['6088_01', '06:09:00', 'Gwiaździsta', 'TP-GWI', 0, 1680.0, 10.87806],
#  ['6040_05', '06:11:00', 'Gwiaździsta', 'TP-GWI', 0, 1800.0, 11.29773],
#  ['6094_05', '06:12:00', 'Gwiaździsta', 'TP-GWI', 0, 1860.0, 11.59084],
#  ['6098_01', '06:13:00', 'Gwiaździsta', 'TP-GWI', 0, 1920.0, 11.87256],
#  ['6003_09', '06:15:00', 'Gwiaździsta', 'TP-GWI', 0, 2040.0, 12.31164],
#  ['6003_04', '06:17:00', 'Gwiaździsta', 'TP-GWI', 0, 2160.0, 12.47587],
#  ['6076_02', '06:18:00', 'Gwiaździsta', 'TP-GWI', 0, 2220.0, 12.84712],
#  ['6078_02', '06:19:00', 'Gwiaździsta', 'TP-GWI', 0, 2280.0, 13.24607],
#  ['6079_02', '06:21:00', 'Gwiaździsta', 'TP-GWI', 0, 2400.0, 13.63593],
#  ['6080_02', '06:22:00', 'Gwiaździsta', 'TP-GWI', 0, 2460.0, 14.0053],
#  ['6082_02', '06:23:00', 'Gwiaździsta', 'TP-GWI', 0, 2520.0, 14.80601],
#  ['6081_02', '06:23:00', 'Gwiaździsta', 'TP-GWI', 0, 2520.0, 15.09508],
#  ['6082_06', '06:36:00', 'os.Górczewska', 'TP-GOR', 1, 3300.0, 15.58569],
#  ['6082_01', '06:37:00', 'os.Górczewska', 'TP-GOR', 1, 3360.0, 15.94626],
#  ['6081_01', '06:37:00', 'os.Górczewska', 'TP-GOR', 1, 3360.0, 16.17695],
#  ['6080_01', '06:38:00', 'os.Górczewska', 'TP-GOR', 1, 3420.0, 16.70639],
#  ['6079_01', '06:39:00', 'os.Górczewska', 'TP-GOR', 1, 3480.0, 17.08048],
#  ['6078_01', '06:40:00', 'os.Górczewska', 'TP-GOR', 1, 3540.0, 17.44519],
#  ['6077_01', '06:41:00', 'os.Górczewska', 'TP-GOR', 1, 3600.0, 17.63147],
#  ['6076_01', '06:42:00', 'os.Górczewska', 'TP-GOR', 1, 3660.0, 17.86617],
#  ['6003_03', '06:43:00', 'os.Górczewska', 'TP-GOR', 1, 3720.0, 18.23097],
#  ['6003_06', '06:44:00', 'os.Górczewska', 'TP-GOR', 1, 3780.0, 18.36909],
#  ['6098_02', '06:45:00', 'os.Górczewska', 'TP-GOR', 1, 3840.0, 18.61937],
#  ['6094_06', '06:46:00', 'os.Górczewska', 'TP-GOR', 1, 3900.0, 19.07291],
#  ['6040_06', '06:48:00', 'os.Górczewska', 'TP-GOR', 1, 4020.0, 19.44845],
#  ['6088_02', '06:49:00', 'os.Górczewska', 'TP-GOR', 1, 4080.0, 19.77968],
#  ['6091_02', '06:50:00', 'os.Górczewska', 'TP-GOR', 1, 4140.0, 20.32936],
#  ['6093_02', '06:51:00', 'os.Górczewska', 'TP-GOR', 1, 4200.0, 20.6355],
#  ['6129_02', '06:52:00', 'os.Górczewska', 'TP-GOR', 1, 4260.0, 21.00338],
#  ['6155_03', '06:53:00', 'os.Górczewska', 'TP-GOR', 1, 4320.0, 21.58388],
#  ['6131_02', '06:55:00', 'os.Górczewska', 'TP-GOR', 1, 4440.0, 21.86975],
#  ['6132_02', '06:56:00', 'os.Górczewska', 'TP-GOR', 1, 4500.0, 22.27519],
#  ['6047_01', '06:58:00', 'os.Górczewska', 'TP-GOR', 1, 4620.0, 22.74569],
#  ['5065_02', '06:59:00', 'os.Górczewska', 'TP-GOR', 1, 4680.0, 23.04751],
#  ['5062_03', '07:01:00', 'os.Górczewska', 'TP-GOR', 1, 4800.0, 23.63226],
#  ['5102_02', '07:03:00', 'os.Górczewska', 'TP-GOR', 1, 4920.0, 24.2504],
#  ['5064_04', '07:05:00', 'os.Górczewska', 'TP-GOR', 1, 5040.0, 24.90047],
#  ['5107_02', '07:06:00', 'os.Górczewska', 'TP-GOR', 1, 5100.0, 25.29031],
#  ['5106_02', '07:08:00', 'os.Górczewska', 'TP-GOR', 1, 5220.0, 25.84059],
#  ['5063_04', '07:10:00', 'os.Górczewska', 'TP-GOR', 1, 5340.0, 26.45433],
#  ['5110_02', '07:11:00', 'os.Górczewska', 'TP-GOR', 1, 5400.0, 26.97979],
#  ['5055_01', '07:12:00', 'os.Górczewska', 'TP-GOR', 1, 5460.0, 27.62787],
#  ['5054_01', '07:13:00', 'os.Górczewska', 'TP-GOR', 1, 5520.0, 27.98305],
#  ['5053_01', '07:14:00', 'os.Górczewska', 'TP-GOR', 1, 5580.0, 28.43972],
#  ['5163_01', '07:16:00', 'os.Górczewska', 'TP-GOR', 1, 5700.0, 28.74575],
#  ['5052_01', '07:18:00', 'os.Górczewska', 'TP-GOR', 1, 5820.0, 29.07103],
#  ['5051_01', '07:19:00', 'os.Górczewska', 'TP-GOR', 1, 5880.0, 29.58059],
#  ['5050_03', '07:21:00', 'os.Górczewska', 'TP-GOR', 1, 6000.0, 29.80023],
#  ['5050_08', '07:36:00', 'Gwiaździsta', 'TP-GWI', 2, 6900.0, 29.92561],
#  ['5050_02', '07:37:00', 'Gwiaździsta', 'TP-GWI', 2, 6960.0, 30.15821],
#  ['5051_02', '07:39:00', 'Gwiaździsta', 'TP-GWI', 2, 7080.0, 30.43875],
#  ['5052_02', '07:41:00', 'Gwiaździsta', 'TP-GWI', 2, 7200.0, 31.00649],
#  ['5163_02', '07:42:00', 'Gwiaździsta', 'TP-GWI', 2, 7260.0, 31.22645],
#  ['5053_02', '07:43:00', 'Gwiaździsta', 'TP-GWI', 2, 7320.0, 31.54559],
#  ['5054_02', '07:44:00', 'Gwiaździsta', 'TP-GWI', 2, 7380.0, 31.93912],
#  ['5055_07', '07:45:00', 'Gwiaździsta', 'TP-GWI', 2, 7440.0, 32.17492],
#  ['5110_01', '07:46:00', 'Gwiaździsta', 'TP-GWI', 2, 7500.0, 32.6922],
#  ['5063_03', '07:48:00', 'Gwiaździsta', 'TP-GWI', 2, 7620.0, 33.41429],
#  ['5106_01', '07:50:00', 'Gwiaździsta', 'TP-GWI', 2, 7740.0, 33.94323],
#  ['5107_01', '07:51:00', 'Gwiaździsta', 'TP-GWI', 2, 7800.0, 34.35346],
#  ['5064_07', '07:53:00', 'Gwiaździsta', 'TP-GWI', 2, 7920.0, 35.01065],
#  ['5102_01', '07:55:00', 'Gwiaździsta', 'TP-GWI', 2, 8040.0, 35.60296],
#  ['5062_01', '07:57:00', 'Gwiaździsta', 'TP-GWI', 2, 8160.0, 36.27967],
#  ['5065_01', '08:00:00', 'Gwiaździsta', 'TP-GWI', 2, 8340.0, 36.92575],
#  ['6047_03', '08:01:00', 'Gwiaździsta', 'TP-GWI', 2, 8400.0, 37.16177],
#  ['6132_01', '08:03:00', 'Gwiaździsta', 'TP-GWI', 2, 8520.0, 37.7629],
#  ['6131_01', '08:04:00', 'Gwiaździsta', 'TP-GWI', 2, 8580.0, 38.08958],
#  ['6155_01', '08:07:00', 'Gwiaździsta', 'TP-GWI', 2, 8760.0, 38.35295],
#  ['6129_01', '08:09:00', 'Gwiaździsta', 'TP-GWI', 2, 8880.0, 39.06319],
#  ['6093_01', '08:10:00', 'Gwiaździsta', 'TP-GWI', 2, 8940.0, 39.34873],
#  ['6091_04', '08:13:00', 'Gwiaździsta', 'TP-GWI', 2, 9120.0, 39.66944],
#  ['6088_01', '08:14:00', 'Gwiaździsta', 'TP-GWI', 2, 9180.0, 40.16667],
#  ['6040_05', '08:17:00', 'Gwiaździsta', 'TP-GWI', 2, 9360.0, 40.58634],
#  ['6094_05', '08:19:00', 'Gwiaździsta', 'TP-GWI', 2, 9480.0, 40.87945],
#  ['6098_01', '08:20:00', 'Gwiaździsta', 'TP-GWI', 2, 9540.0, 41.16117],
#  ['6003_09', '08:22:00', 'Gwiaździsta', 'TP-GWI', 2, 9660.0, 41.60025],
#  ['6003_04', '08:24:00', 'Gwiaździsta', 'TP-GWI', 2, 9780.0, 41.76448],
#  ['6076_02', '08:25:00', 'Gwiaździsta', 'TP-GWI', 2, 9840.0, 42.13573],
#  ['6078_02', '08:26:00', 'Gwiaździsta', 'TP-GWI', 2, 9900.0, 42.53468],
#  ['6079_02', '08:28:00', 'Gwiaździsta', 'TP-GWI', 2, 10020.0, 42.92454],
#  ['6080_02', '08:29:00', 'Gwiaździsta', 'TP-GWI', 2, 10080.0, 43.29391],
#  ['6082_02', '08:30:00', 'Gwiaździsta', 'TP-GWI', 2, 10140.0, 44.09462],
#  ['6081_02', '08:30:00', 'Gwiaździsta', 'TP-GWI', 2, 10140.0, 44.38369],
#  ['6082_06', '08:42:00', 'os.Górczewska', 'TP-GOR', 3, 10860.0, 44.8743],
#  ['6082_01', '08:43:00', 'os.Górczewska', 'TP-GOR', 3, 10920.0, 45.23487],
#  ['6081_01', '08:43:00', 'os.Górczewska', 'TP-GOR', 3, 10920.0, 45.46556],
#  ['6080_01', '08:44:00', 'os.Górczewska', 'TP-GOR', 3, 10980.0, 45.995],
#  ['6079_01', '08:46:00', 'os.Górczewska', 'TP-GOR', 3, 11100.0, 46.36909],
#  ['6078_01', '08:47:00', 'os.Górczewska', 'TP-GOR', 3, 11160.0, 46.7338],
#  ['6077_01', '08:48:00', 'os.Górczewska', 'TP-GOR', 3, 11220.0, 46.92008],
#  ['6076_01', '08:49:00', 'os.Górczewska', 'TP-GOR', 3, 11280.0, 47.15478],
#  ['6003_03', '08:50:00', 'os.Górczewska', 'TP-GOR', 3, 11340.0, 47.51958],
#  ['6003_06', '08:52:00', 'os.Górczewska', 'TP-GOR', 3, 11460.0, 47.6577],
#  ['6098_02', '08:53:00', 'os.Górczewska', 'TP-GOR', 3, 11520.0, 47.90798],
#  ['6094_06', '08:54:00', 'os.Górczewska', 'TP-GOR', 3, 11580.0, 48.36152],
#  ['6040_06', '08:56:00', 'os.Górczewska', 'TP-GOR', 3, 11700.0, 48.73706],
#  ['6088_02', '08:57:00', 'os.Górczewska', 'TP-GOR', 3, 11760.0, 49.06829],
#  ['6091_02', '08:59:00', 'os.Górczewska', 'TP-GOR', 3, 11880.0, 49.61797],
#  ['6093_02', '09:00:00', 'os.Górczewska', 'TP-GOR', 3, 11940.0, 49.92411],
#  ['6129_02', '09:01:00', 'os.Górczewska', 'TP-GOR', 3, 12000.0, 50.29199],
#  ['6155_03', '09:02:00', 'os.Górczewska', 'TP-GOR', 3, 12060.0, 50.87249],
#  ['6131_02', '09:04:00', 'os.Górczewska', 'TP-GOR', 3, 12180.0, 51.15836],
#  ['6132_02', '09:05:00', 'os.Górczewska', 'TP-GOR', 3, 12240.0, 51.5638],
#  ['6047_01', '09:07:00', 'os.Górczewska', 'TP-GOR', 3, 12360.0, 52.0343],
#  ['5065_02', '09:08:00', 'os.Górczewska', 'TP-GOR', 3, 12420.0, 52.33612],
#  ['5062_03', '09:10:00', 'os.Górczewska', 'TP-GOR', 3, 12540.0, 52.92087],
#  ['5102_02', '09:12:00', 'os.Górczewska', 'TP-GOR', 3, 12660.0, 53.53901],
#  ['5064_04', '09:14:00', 'os.Górczewska', 'TP-GOR', 3, 12780.0, 54.18908],
#  ['5107_02', '09:15:00', 'os.Górczewska', 'TP-GOR', 3, 12840.0, 54.57892],
#  ['5106_02', '09:17:00', 'os.Górczewska', 'TP-GOR', 3, 12960.0, 55.1292],
#  ['5063_04', '09:19:00', 'os.Górczewska', 'TP-GOR', 3, 13080.0, 55.74294],
#  ['5110_02', '09:20:00', 'os.Górczewska', 'TP-GOR', 3, 13140.0, 56.2684],
#  ['5055_01', '09:21:00', 'os.Górczewska', 'TP-GOR', 3, 13200.0, 56.91648],
#  ['5054_01', '09:22:00', 'os.Górczewska', 'TP-GOR', 3, 13260.0, 57.27166],
#  ['5053_01', '09:23:00', 'os.Górczewska', 'TP-GOR', 3, 13320.0, 57.72833],
#  ['5163_01', '09:24:00', 'os.Górczewska', 'TP-GOR', 3, 13380.0, 58.03436],
#  ['5052_01', '09:25:00', 'os.Górczewska', 'TP-GOR', 3, 13440.0, 58.35964],
#  ['5051_01', '09:26:00', 'os.Górczewska', 'TP-GOR', 3, 13500.0, 58.8692],
#  ['5050_03', '09:28:00', 'os.Górczewska', 'TP-GOR', 3, 13620.0, 59.08884],
#  ['5050_08', '09:38:00', 'Gwiaździsta', 'TP-GWI', 4, 14220.0, 59.21422],
#  ['5050_02', '09:39:00', 'Gwiaździsta', 'TP-GWI', 4, 14280.0, 59.44682],
#  ['5051_02', '09:40:00', 'Gwiaździsta', 'TP-GWI', 4, 14340.0, 59.72736],
#  ['5052_02', '09:41:00', 'Gwiaździsta', 'TP-GWI', 4, 14400.0, 60.2951],
#  ['5163_02', '09:42:00', 'Gwiaździsta', 'TP-GWI', 4, 14460.0, 60.51506],
#  ['5053_02', '09:43:00', 'Gwiaździsta', 'TP-GWI', 4, 14520.0, 60.8342],
#  ['5054_02', '09:44:00', 'Gwiaździsta', 'TP-GWI', 4, 14580.0, 61.22773],
#  ['5055_07', '09:45:00', 'Gwiaździsta', 'TP-GWI', 4, 14640.0, 61.46353],
#  ['5110_01', '09:46:00', 'Gwiaździsta', 'TP-GWI', 4, 14700.0, 61.98081],
#  ['5063_03', '09:48:00', 'Gwiaździsta', 'TP-GWI', 4, 14820.0, 62.7029],
#  ['5106_01', '09:50:00', 'Gwiaździsta', 'TP-GWI', 4, 14940.0, 63.23184],
#  ['5107_01', '09:51:00', 'Gwiaździsta', 'TP-GWI', 4, 15000.0, 63.64207],
#  ['5064_07', '09:53:00', 'Gwiaździsta', 'TP-GWI', 4, 15120.0, 64.29926],
#  ['5102_01', '09:54:00', 'Gwiaździsta', 'TP-GWI', 4, 15180.0, 64.89157],
#  ['5062_01', '09:56:00', 'Gwiaździsta', 'TP-GWI', 4, 15300.0, 65.56828],
#  ['5065_01', '09:58:00', 'Gwiaździsta', 'TP-GWI', 4, 15420.0, 66.21436],
#  ['6047_03', '09:59:00', 'Gwiaździsta', 'TP-GWI', 4, 15480.0, 66.45038],
#  ['6132_01', '10:01:00', 'Gwiaździsta', 'TP-GWI', 4, 15600.0, 67.05151],
#  ['6131_01', '10:02:00', 'Gwiaździsta', 'TP-GWI', 4, 15660.0, 67.37819],
#  ['6155_01', '10:04:00', 'Gwiaździsta', 'TP-GWI', 4, 15780.0, 67.64156],
#  ['6129_01', '10:06:00', 'Gwiaździsta', 'TP-GWI', 4, 15900.0, 68.3518],
#  ['6093_01', '10:07:00', 'Gwiaździsta', 'TP-GWI', 4, 15960.0, 68.63734],
#  ['6091_04', '10:08:00', 'Gwiaździsta', 'TP-GWI', 4, 16020.0, 68.95805],
#  ['6088_01', '10:09:00', 'Gwiaździsta', 'TP-GWI', 4, 16080.0, 69.45528],
#  ['6040_05', '10:11:00', 'Gwiaździsta', 'TP-GWI', 4, 16200.0, 69.87495],
#  ['6094_05', '10:12:00', 'Gwiaździsta', 'TP-GWI', 4, 16260.0, 70.16806],
#  ['6098_01', '10:13:00', 'Gwiaździsta', 'TP-GWI', 4, 16320.0, 70.44978],
#  ['6003_09', '10:15:00', 'Gwiaździsta', 'TP-GWI', 4, 16440.0, 70.88886],
#  ['6003_04', '10:17:00', 'Gwiaździsta', 'TP-GWI', 4, 16560.0, 71.05309],
#  ['6076_02', '10:18:00', 'Gwiaździsta', 'TP-GWI', 4, 16620.0, 71.42434],
#  ['6078_02', '10:19:00', 'Gwiaździsta', 'TP-GWI', 4, 16680.0, 71.82329],
#  ['6079_02', '10:21:00', 'Gwiaździsta', 'TP-GWI', 4, 16800.0, 72.21315],
#  ['6080_02', '10:22:00', 'Gwiaździsta', 'TP-GWI', 4, 16860.0, 72.58252],
#  ['6082_02', '10:23:00', 'Gwiaździsta', 'TP-GWI', 4, 16920.0, 73.38323],
#  ['6081_02', '10:23:00', 'Gwiaździsta', 'TP-GWI', 4, 16920.0, 73.6723],
#  ['6082_06', '10:46:00', 'os.Górczewska', 'TP-GOR', 5, 18300.0, 74.16291],
#  ['6082_01', '10:47:00', 'os.Górczewska', 'TP-GOR', 5, 18360.0, 74.52348],
#  ['6081_01', '10:47:00', 'os.Górczewska', 'TP-GOR', 5, 18360.0, 74.75417],
#  ['6080_01', '10:48:00', 'os.Górczewska', 'TP-GOR', 5, 18420.0, 75.28361],
#  ['6079_01', '10:49:00', 'os.Górczewska', 'TP-GOR', 5, 18480.0, 75.6577],
#  ['6078_01', '10:50:00', 'os.Górczewska', 'TP-GOR', 5, 18540.0, 76.02241],
#  ['6077_01', '10:51:00', 'os.Górczewska', 'TP-GOR', 5, 18600.0, 76.20869],
#  ['6076_01', '10:52:00', 'os.Górczewska', 'TP-GOR', 5, 18660.0, 76.44339],
#  ['6003_03', '10:53:00', 'os.Górczewska', 'TP-GOR', 5, 18720.0, 76.80819],
#  ['6003_06', '10:55:00', 'os.Górczewska', 'TP-GOR', 5, 18840.0, 76.94631],
#  ['6098_02', '10:56:00', 'os.Górczewska', 'TP-GOR', 5, 18900.0, 77.19659],
#  ['6094_06', '10:57:00', 'os.Górczewska', 'TP-GOR', 5, 18960.0, 77.65013],
#  ['6040_06', '10:59:00', 'os.Górczewska', 'TP-GOR', 5, 19080.0, 78.02567],
#  ['6088_02', '11:00:00', 'os.Górczewska', 'TP-GOR', 5, 19140.0, 78.3569],
#  ['6091_02', '11:01:00', 'os.Górczewska', 'TP-GOR', 5, 19200.0, 78.90658],
#  ['6093_02', '11:02:00', 'os.Górczewska', 'TP-GOR', 5, 19260.0, 79.21272],
#  ['6129_02', '11:03:00', 'os.Górczewska', 'TP-GOR', 5, 19320.0, 79.5806],
#  ['6155_03', '11:04:00', 'os.Górczewska', 'TP-GOR', 5, 19380.0, 80.1611],
#  ['6131_02', '11:06:00', 'os.Górczewska', 'TP-GOR', 5, 19500.0, 80.44697],
#  ['6132_02', '11:07:00', 'os.Górczewska', 'TP-GOR', 5, 19560.0, 80.85241],
#  ['6047_01', '11:09:00', 'os.Górczewska', 'TP-GOR', 5, 19680.0, 81.32291],
#  ['5065_02', '11:10:00', 'os.Górczewska', 'TP-GOR', 5, 19740.0, 81.62473],
#  ['5062_03', '11:12:00', 'os.Górczewska', 'TP-GOR', 5, 19860.0, 82.20948],
#  ['5102_02', '11:14:00', 'os.Górczewska', 'TP-GOR', 5, 19980.0, 82.82762],
#  ['5064_04', '11:16:00', 'os.Górczewska', 'TP-GOR', 5, 20100.0, 83.47769],
#  ['5107_02', '11:17:00', 'os.Górczewska', 'TP-GOR', 5, 20160.0, 83.86753],
#  ['5106_02', '11:19:00', 'os.Górczewska', 'TP-GOR', 5, 20280.0, 84.41781],
#  ['5063_04', '11:21:00', 'os.Górczewska', 'TP-GOR', 5, 20400.0, 85.03155],
#  ['5110_02', '11:22:00', 'os.Górczewska', 'TP-GOR', 5, 20460.0, 85.55701],
#  ['5055_01', '11:23:00', 'os.Górczewska', 'TP-GOR', 5, 20520.0, 86.20509],
#  ['5054_01', '11:24:00', 'os.Górczewska', 'TP-GOR', 5, 20580.0, 86.56027],
#  ['5053_01', '11:25:00', 'os.Górczewska', 'TP-GOR', 5, 20640.0, 87.01694],
#  ['5163_01', '11:26:00', 'os.Górczewska', 'TP-GOR', 5, 20700.0, 87.32297],
#  ['5052_01', '11:27:00', 'os.Górczewska', 'TP-GOR', 5, 20760.0, 87.64825],
#  ['5051_01', '11:28:00', 'os.Górczewska', 'TP-GOR', 5, 20820.0, 88.15781],
#  ['5050_03', '11:30:00', 'os.Górczewska', 'TP-GOR', 5, 20940.0, 88.37745],
#  ['5050_08', '11:53:00', 'Gwiaździsta', 'TP-GWI', 6, 22320.0, 88.50283],
#  ['5050_02', '11:54:00', 'Gwiaździsta', 'TP-GWI', 6, 22380.0, 88.73543],
#  ['5051_02', '11:55:00', 'Gwiaździsta', 'TP-GWI', 6, 22440.0, 89.01597],
#  ['5052_02', '11:56:00', 'Gwiaździsta', 'TP-GWI', 6, 22500.0, 89.58371],
#  ['5163_02', '11:57:00', 'Gwiaździsta', 'TP-GWI', 6, 22560.0, 89.80367],
#  ['5053_02', '11:58:00', 'Gwiaździsta', 'TP-GWI', 6, 22620.0, 90.12281],
#  ['5054_02', '11:59:00', 'Gwiaździsta', 'TP-GWI', 6, 22680.0, 90.51634],
#  ['5055_07', '12:00:00', 'Gwiaździsta', 'TP-GWI', 6, 22740.0, 90.75214],
#  ['5110_01', '12:01:00', 'Gwiaździsta', 'TP-GWI', 6, 22800.0, 91.26942],
#  ['5063_03', '12:03:00', 'Gwiaździsta', 'TP-GWI', 6, 22920.0, 91.99151],
#  ['5106_01', '12:05:00', 'Gwiaździsta', 'TP-GWI', 6, 23040.0, 92.52045],
#  ['5107_01', '12:06:00', 'Gwiaździsta', 'TP-GWI', 6, 23100.0, 92.93068],
#  ['5064_07', '12:08:00', 'Gwiaździsta', 'TP-GWI', 6, 23220.0, 93.58787],
#  ['5102_01', '12:09:00', 'Gwiaździsta', 'TP-GWI', 6, 23280.0, 94.18018],
#  ['5062_01', '12:11:00', 'Gwiaździsta', 'TP-GWI', 6, 23400.0, 94.85689],
#  ['5065_01', '12:13:00', 'Gwiaździsta', 'TP-GWI', 6, 23520.0, 95.50297],
#  ['6047_03', '12:14:00', 'Gwiaździsta', 'TP-GWI', 6, 23580.0, 95.73899],
#  ['6132_01', '12:16:00', 'Gwiaździsta', 'TP-GWI', 6, 23700.0, 96.34012],
#  ['6131_01', '12:17:00', 'Gwiaździsta', 'TP-GWI', 6, 23760.0, 96.6668],
#  ['6155_01', '12:19:00', 'Gwiaździsta', 'TP-GWI', 6, 23880.0, 96.93017],
#  ['6129_01', '12:21:00', 'Gwiaździsta', 'TP-GWI', 6, 24000.0, 97.64041],
#  ['6093_01', '12:22:00', 'Gwiaździsta', 'TP-GWI', 6, 24060.0, 97.92595],
#  ['6091_04', '12:23:00', 'Gwiaździsta', 'TP-GWI', 6, 24120.0, 98.24666],
#  ['6088_01', '12:24:00', 'Gwiaździsta', 'TP-GWI', 6, 24180.0, 98.74389],
#  ['6040_05', '12:26:00', 'Gwiaździsta', 'TP-GWI', 6, 24300.0, 99.16356],
#  ['6094_05', '12:27:00', 'Gwiaździsta', 'TP-GWI', 6, 24360.0, 99.45667],
#  ['6098_01', '12:28:00', 'Gwiaździsta', 'TP-GWI', 6, 24420.0, 99.73839],
#  ['6003_09', '12:30:00', 'Gwiaździsta', 'TP-GWI', 6, 24540.0, 100.17747],
#  ['6003_04', '12:32:00', 'Gwiaździsta', 'TP-GWI', 6, 24660.0, 100.3417],
#  ['6076_02', '12:33:00', 'Gwiaździsta', 'TP-GWI', 6, 24720.0, 100.71295],
#  ['6078_02', '12:34:00', 'Gwiaździsta', 'TP-GWI', 6, 24780.0, 101.1119],
#  ['6079_02', '12:36:00', 'Gwiaździsta', 'TP-GWI', 6, 24900.0, 101.50176],
#  ['6080_02', '12:37:00', 'Gwiaździsta', 'TP-GWI', 6, 24960.0, 101.87113],
#  ['6082_02', '12:38:00', 'Gwiaździsta', 'TP-GWI', 6, 25020.0, 102.67184],
#  ['6081_02', '12:38:00', 'Gwiaździsta', 'TP-GWI', 6, 25020.0, 102.96091],
#  ['6082_06', '13:01:00', 'os.Górczewska', 'TP-GOR', 7, 26400.0, 103.45152],
#  ['6082_01', '13:02:00', 'os.Górczewska', 'TP-GOR', 7, 26460.0, 103.81209],
#  ['6081_01', '13:02:00', 'os.Górczewska', 'TP-GOR', 7, 26460.0, 104.04278],
#  ['6080_01', '13:03:00', 'os.Górczewska', 'TP-GOR', 7, 26520.0, 104.57222],
#  ['6079_01', '13:04:00', 'os.Górczewska', 'TP-GOR', 7, 26580.0, 104.94631],
#  ['6078_01', '13:05:00', 'os.Górczewska', 'TP-GOR', 7, 26640.0, 105.31102],
#  ['6077_01', '13:06:00', 'os.Górczewska', 'TP-GOR', 7, 26700.0, 105.4973],
#  ['6076_01', '13:07:00', 'os.Górczewska', 'TP-GOR', 7, 26760.0, 105.732],
#  ['6003_03', '13:08:00', 'os.Górczewska', 'TP-GOR', 7, 26820.0, 106.0968],
#  ['6003_06', '13:10:00', 'os.Górczewska', 'TP-GOR', 7, 26940.0, 106.23492],
#  ['6098_02', '13:11:00', 'os.Górczewska', 'TP-GOR', 7, 27000.0, 106.4852],
#  ['6094_06', '13:12:00', 'os.Górczewska', 'TP-GOR', 7, 27060.0, 106.93874],
#  ['6040_06', '13:14:00', 'os.Górczewska', 'TP-GOR', 7, 27180.0, 107.31428],
#  ['6088_02', '13:15:00', 'os.Górczewska', 'TP-GOR', 7, 27240.0, 107.64551],
#  ['6091_02', '13:16:00', 'os.Górczewska', 'TP-GOR', 7, 27300.0, 108.19519],
#  ['6093_02', '13:17:00', 'os.Górczewska', 'TP-GOR', 7, 27360.0, 108.50133],
#  ['6129_02', '13:18:00', 'os.Górczewska', 'TP-GOR', 7, 27420.0, 108.86921],
#  ['6155_03', '13:19:00', 'os.Górczewska', 'TP-GOR', 7, 27480.0, 109.44971],
#  ['6131_02', '13:21:00', 'os.Górczewska', 'TP-GOR', 7, 27600.0, 109.73558],
#  ['6132_02', '13:22:00', 'os.Górczewska', 'TP-GOR', 7, 27660.0, 110.14102],
#  ['6047_01', '13:24:00', 'os.Górczewska', 'TP-GOR', 7, 27780.0, 110.61152],
#  ['5065_02', '13:25:00', 'os.Górczewska', 'TP-GOR', 7, 27840.0, 110.91334],
#  ['5062_03', '13:27:00', 'os.Górczewska', 'TP-GOR', 7, 27960.0, 111.49809],
#  ['5102_02', '13:29:00', 'os.Górczewska', 'TP-GOR', 7, 28080.0, 112.11623],
#  ['5064_04', '13:31:00', 'os.Górczewska', 'TP-GOR', 7, 28200.0, 112.7663],
#  ['5107_02', '13:32:00', 'os.Górczewska', 'TP-GOR', 7, 28260.0, 113.15614],
#  ['5106_02', '13:34:00', 'os.Górczewska', 'TP-GOR', 7, 28380.0, 113.70642],
#  ['5063_04', '13:36:00', 'os.Górczewska', 'TP-GOR', 7, 28500.0, 114.32016],
#  ['5110_02', '13:37:00', 'os.Górczewska', 'TP-GOR', 7, 28560.0, 114.84562],
#  ['5055_01', '13:38:00', 'os.Górczewska', 'TP-GOR', 7, 28620.0, 115.4937],
#  ['5054_01', '13:39:00', 'os.Górczewska', 'TP-GOR', 7, 28680.0, 115.84888],
#  ['5053_01', '13:40:00', 'os.Górczewska', 'TP-GOR', 7, 28740.0, 116.30555],
#  ['5163_01', '13:41:00', 'os.Górczewska', 'TP-GOR', 7, 28800.0, 116.61158],
#  ['5052_01', '13:42:00', 'os.Górczewska', 'TP-GOR', 7, 28860.0, 116.93686],
#  ['5051_01', '13:43:00', 'os.Górczewska', 'TP-GOR', 7, 28920.0, 117.44642],
#  ['5050_03', '13:45:00', 'os.Górczewska', 'TP-GOR', 7, 29040.0, 117.66606],
#  ['5050_08', '14:02:00', 'Gwiaździsta', 'TP-GWI', 8, 30060.0, 117.79144],
#  ['5050_02', '14:03:00', 'Gwiaździsta', 'TP-GWI', 8, 30120.0, 118.02404],
#  ['5051_02', '14:04:00', 'Gwiaździsta', 'TP-GWI', 8, 30180.0, 118.30458],
#  ['5052_02', '14:06:00', 'Gwiaździsta', 'TP-GWI', 8, 30300.0, 118.87232],
#  ['5163_02', '14:07:00', 'Gwiaździsta', 'TP-GWI', 8, 30360.0, 119.09228],
#  ['5053_02', '14:08:00', 'Gwiaździsta', 'TP-GWI', 8, 30420.0, 119.41142],
#  ['5054_02', '14:09:00', 'Gwiaździsta', 'TP-GWI', 8, 30480.0, 119.80495],
#  ['5055_07', '14:10:00', 'Gwiaździsta', 'TP-GWI', 8, 30540.0, 120.04075],
#  ['5110_01', '14:11:00', 'Gwiaździsta', 'TP-GWI', 8, 30600.0, 120.55803],
#  ['5063_03', '14:13:00', 'Gwiaździsta', 'TP-GWI', 8, 30720.0, 121.28012],
#  ['5106_01', '14:15:00', 'Gwiaździsta', 'TP-GWI', 8, 30840.0, 121.80906],
#  ['5107_01', '14:16:00', 'Gwiaździsta', 'TP-GWI', 8, 30900.0, 122.21929],
#  ['5064_07', '14:18:00', 'Gwiaździsta', 'TP-GWI', 8, 31020.0, 122.87648],
#  ['5102_01', '14:20:00', 'Gwiaździsta', 'TP-GWI', 8, 31140.0, 123.46879],
#  ['5062_01', '14:22:00', 'Gwiaździsta', 'TP-GWI', 8, 31260.0, 124.1455],
#  ['5065_01', '14:24:00', 'Gwiaździsta', 'TP-GWI', 8, 31380.0, 124.79158],
#  ['6047_03', '14:25:00', 'Gwiaździsta', 'TP-GWI', 8, 31440.0, 125.0276],
#  ['6132_01', '14:27:00', 'Gwiaździsta', 'TP-GWI', 8, 31560.0, 125.62873],
#  ['6131_01', '14:28:00', 'Gwiaździsta', 'TP-GWI', 8, 31620.0, 125.95541],
#  ['6155_01', '14:30:00', 'Gwiaździsta', 'TP-GWI', 8, 31740.0, 126.21878],
#  ['6129_01', '14:32:00', 'Gwiaździsta', 'TP-GWI', 8, 31860.0, 126.92902],
#  ['6093_01', '14:33:00', 'Gwiaździsta', 'TP-GWI', 8, 31920.0, 127.21456],
#  ['6091_04', '14:34:00', 'Gwiaździsta', 'TP-GWI', 8, 31980.0, 127.53527],
#  ['6088_01', '14:35:00', 'Gwiaździsta', 'TP-GWI', 8, 32040.0, 128.0325],
#  ['6040_05', '14:37:00', 'Gwiaździsta', 'TP-GWI', 8, 32160.0, 128.45217],
#  ['6094_05', '14:38:00', 'Gwiaździsta', 'TP-GWI', 8, 32220.0, 128.74528],
#  ['6098_01', '14:39:00', 'Gwiaździsta', 'TP-GWI', 8, 32280.0, 129.027],
#  ['6003_09', '14:41:00', 'Gwiaździsta', 'TP-GWI', 8, 32400.0, 129.46608],
#  ['6003_04', '14:43:00', 'Gwiaździsta', 'TP-GWI', 8, 32520.0, 129.63031],
#  ['6076_02', '14:44:00', 'Gwiaździsta', 'TP-GWI', 8, 32580.0, 130.00156],
#  ['6078_02', '14:45:00', 'Gwiaździsta', 'TP-GWI', 8, 32640.0, 130.40051],
#  ['6079_02', '14:47:00', 'Gwiaździsta', 'TP-GWI', 8, 32760.0, 130.79037],
#  ['6080_02', '14:48:00', 'Gwiaździsta', 'TP-GWI', 8, 32820.0, 131.15974],
#  ['6081_02', '14:49:00', 'Gwiaździsta', 'TP-GWI', 8, 32880.0, 131.67677],
#  ['6082_02', '14:49:00', 'Gwiaździsta', 'TP-GWI', 8, 32880.0, 131.96584],
#  ['6082_06', '15:17:00', 'os.Górczewska', 'TP-GOR', 9, 34560.0, 132.17811],
#  ['6081_01', '15:18:00', 'os.Górczewska', 'TP-GOR', 9, 34620.0, 132.76181],
#  ['6082_01', '15:18:00', 'os.Górczewska', 'TP-GOR', 9, 34620.0, 132.9925],
#  ['6080_01', '15:19:00', 'os.Górczewska', 'TP-GOR', 9, 34680.0, 133.74737],
#  ['6079_01', '15:21:00', 'os.Górczewska', 'TP-GOR', 9, 34800.0, 134.12146],
#  ['6078_01', '15:22:00', 'os.Górczewska', 'TP-GOR', 9, 34860.0, 134.48617],
#  ['6077_01', '15:23:00', 'os.Górczewska', 'TP-GOR', 9, 34920.0, 134.67245],
#  ['6076_01', '15:24:00', 'os.Górczewska', 'TP-GOR', 9, 34980.0, 134.90715],
#  ['6003_03', '15:25:00', 'os.Górczewska', 'TP-GOR', 9, 35040.0, 135.27195],
#  ['6003_06', '15:27:00', 'os.Górczewska', 'TP-GOR', 9, 35160.0, 135.41007],
#  ['6098_02', '15:28:00', 'os.Górczewska', 'TP-GOR', 9, 35220.0, 135.66035],
#  ['6094_06', '15:29:00', 'os.Górczewska', 'TP-GOR', 9, 35280.0, 136.11389],
#  ['6040_06', '15:31:00', 'os.Górczewska', 'TP-GOR', 9, 35400.0, 136.48943],
#  ['6088_02', '15:32:00', 'os.Górczewska', 'TP-GOR', 9, 35460.0, 136.82066],
#  ['6091_02', '15:34:00', 'os.Górczewska', 'TP-GOR', 9, 35580.0, 137.37034],
#  ['6093_02', '15:35:00', 'os.Górczewska', 'TP-GOR', 9, 35640.0, 137.67648],
#  ['6129_02', '15:36:00', 'os.Górczewska', 'TP-GOR', 9, 35700.0, 138.04436],
#  ['6155_03', '15:38:00', 'os.Górczewska', 'TP-GOR', 9, 35820.0, 138.62486],
#  ['6131_02', '15:40:00', 'os.Górczewska', 'TP-GOR', 9, 35940.0, 138.91073],
#  ['6132_02', '15:41:00', 'os.Górczewska', 'TP-GOR', 9, 36000.0, 139.31617],
#  ['6047_01', '15:43:00', 'os.Górczewska', 'TP-GOR', 9, 36120.0, 139.78667],
#  ['5065_02', '15:44:00', 'os.Górczewska', 'TP-GOR', 9, 36180.0, 140.08849],
#  ['5062_03', '15:46:00', 'os.Górczewska', 'TP-GOR', 9, 36300.0, 140.67324],
#  ['5102_02', '15:48:00', 'os.Górczewska', 'TP-GOR', 9, 36420.0, 141.29138],
#  ['5064_04', '15:50:00', 'os.Górczewska', 'TP-GOR', 9, 36540.0, 141.94145],
#  ['5107_02', '15:52:00', 'os.Górczewska', 'TP-GOR', 9, 36660.0, 142.33129],
#  ['5106_02', '15:54:00', 'os.Górczewska', 'TP-GOR', 9, 36780.0, 142.88157],
#  ['5063_04', '15:56:00', 'os.Górczewska', 'TP-GOR', 9, 36900.0, 143.49531],
#  ['5110_02', '15:57:00', 'os.Górczewska', 'TP-GOR', 9, 36960.0, 144.02077],
#  ['5055_01', '15:59:00', 'os.Górczewska', 'TP-GOR', 9, 37080.0, 144.66885],
#  ['5054_01', '16:00:00', 'os.Górczewska', 'TP-GOR', 9, 37140.0, 145.02403],
#  ['5053_01', '16:01:00', 'os.Górczewska', 'TP-GOR', 9, 37200.0, 145.4807],
#  ['5163_01', '16:03:00', 'os.Górczewska', 'TP-GOR', 9, 37320.0, 145.78673],
#  ['5052_01', '16:05:00', 'os.Górczewska', 'TP-GOR', 9, 37440.0, 146.11201],
#  ['5051_01', '16:06:00', 'os.Górczewska', 'TP-GOR', 9, 37500.0, 146.62157],
#  ['5050_03', '16:08:00', 'os.Górczewska', 'TP-GOR', 9, 37620.0, 146.84121],
#  ['5050_08', '16:18:00', 'Gwiaździsta', 'TP-GWI', 10, 38220.0, 146.96659],
#  ['5050_02', '16:19:00', 'Gwiaździsta', 'TP-GWI', 10, 38280.0, 147.19919],
#  ['5051_02', '16:21:00', 'Gwiaździsta', 'TP-GWI', 10, 38400.0, 147.47973],
#  ['5052_02', '16:23:00', 'Gwiaździsta', 'TP-GWI', 10, 38520.0, 148.04747],
#  ['5163_02', '16:25:00', 'Gwiaździsta', 'TP-GWI', 10, 38640.0, 148.26743],
#  ['5053_02', '16:26:00', 'Gwiaździsta', 'TP-GWI', 10, 38700.0, 148.58657],
#  ['5054_02', '16:28:00', 'Gwiaździsta', 'TP-GWI', 10, 38820.0, 148.9801],
#  ['5055_07', '16:30:00', 'Gwiaździsta', 'TP-GWI', 10, 38940.0, 149.2159],
#  ['5110_01', '16:31:00', 'Gwiaździsta', 'TP-GWI', 10, 39000.0, 149.73318],
#  ['5063_03', '16:33:00', 'Gwiaździsta', 'TP-GWI', 10, 39120.0, 150.45527],
#  ['5106_01', '16:35:00', 'Gwiaździsta', 'TP-GWI', 10, 39240.0, 150.98421],
#  ['5107_01', '16:36:00', 'Gwiaździsta', 'TP-GWI', 10, 39300.0, 151.39444],
#  ['5064_07', '16:38:00', 'Gwiaździsta', 'TP-GWI', 10, 39420.0, 152.05163],
#  ['5102_01', '16:40:00', 'Gwiaździsta', 'TP-GWI', 10, 39540.0, 152.64394],
#  ['5062_01', '16:42:00', 'Gwiaździsta', 'TP-GWI', 10, 39660.0, 153.32065],
#  ['5065_01', '16:44:00', 'Gwiaździsta', 'TP-GWI', 10, 39780.0, 153.96673],
#  ['6047_03', '16:45:00', 'Gwiaździsta', 'TP-GWI', 10, 39840.0, 154.20275],
#  ['6132_01', '16:47:00', 'Gwiaździsta', 'TP-GWI', 10, 39960.0, 154.80388],
#  ['6131_01', '16:48:00', 'Gwiaździsta', 'TP-GWI', 10, 40020.0, 155.13056],
#  ['6155_01', '16:50:00', 'Gwiaździsta', 'TP-GWI', 10, 40140.0, 155.39393],
#  ['6129_01', '16:52:00', 'Gwiaździsta', 'TP-GWI', 10, 40260.0, 156.10417],
#  ['6093_01', '16:53:00', 'Gwiaździsta', 'TP-GWI', 10, 40320.0, 156.38971],
#  ['6091_04', '16:55:00', 'Gwiaździsta', 'TP-GWI', 10, 40440.0, 156.71042],
#  ['6088_01', '16:56:00', 'Gwiaździsta', 'TP-GWI', 10, 40500.0, 157.20765],
#  ['6040_05', '16:59:00', 'Gwiaździsta', 'TP-GWI', 10, 40680.0, 157.62732],
#  ['6094_05', '17:01:00', 'Gwiaździsta', 'TP-GWI', 10, 40800.0, 157.92043],
#  ['6098_01', '17:02:00', 'Gwiaździsta', 'TP-GWI', 10, 40860.0, 158.20215],
#  ['6003_09', '17:04:00', 'Gwiaździsta', 'TP-GWI', 10, 40980.0, 158.64123],
#  ['6003_04', '17:06:00', 'Gwiaździsta', 'TP-GWI', 10, 41100.0, 158.80546],
#  ['6076_02', '17:07:00', 'Gwiaździsta', 'TP-GWI', 10, 41160.0, 159.17671],
#  ['6078_02', '17:08:00', 'Gwiaździsta', 'TP-GWI', 10, 41220.0, 159.57566],
#  ['6079_02', '17:10:00', 'Gwiaździsta', 'TP-GWI', 10, 41340.0, 159.96552],
#  ['6080_02', '17:11:00', 'Gwiaździsta', 'TP-GWI', 10, 41400.0, 160.33489],
#  ['6082_02', '17:12:00', 'Gwiaździsta', 'TP-GWI', 10, 41460.0, 161.1356],
#  ['6081_02', '17:12:00', 'Gwiaździsta', 'TP-GWI', 10, 41460.0, 161.42467],
#  ['6082_06', '17:27:00', 'os.Górczewska', 'TP-GOR', 11, 42360.0, 161.91528],
#  ['6081_01', '17:28:00', 'os.Górczewska', 'TP-GOR', 11, 42420.0, 162.49898],
#  ['6082_01', '17:28:00', 'os.Górczewska', 'TP-GOR', 11, 42420.0, 162.72967],
#  ['6080_01', '17:29:00', 'os.Górczewska', 'TP-GOR', 11, 42480.0, 163.48454],
#  ['6079_01', '17:31:00', 'os.Górczewska', 'TP-GOR', 11, 42600.0, 163.85863],
#  ['6078_01', '17:32:00', 'os.Górczewska', 'TP-GOR', 11, 42660.0, 164.22334],
#  ['6077_01', '17:33:00', 'os.Górczewska', 'TP-GOR', 11, 42720.0, 164.40962],
#  ['6076_01', '17:34:00', 'os.Górczewska', 'TP-GOR', 11, 42780.0, 164.64432],
#  ['6003_03', '17:35:00', 'os.Górczewska', 'TP-GOR', 11, 42840.0, 165.00912],
#  ['6003_06', '17:37:00', 'os.Górczewska', 'TP-GOR', 11, 42960.0, 165.14724],
#  ['6098_02', '17:38:00', 'os.Górczewska', 'TP-GOR', 11, 43020.0, 165.39752],
#  ['6094_06', '17:39:00', 'os.Górczewska', 'TP-GOR', 11, 43080.0, 165.85106],
#  ['6040_06', '17:41:00', 'os.Górczewska', 'TP-GOR', 11, 43200.0, 166.2266],
#  ['6088_02', '17:42:00', 'os.Górczewska', 'TP-GOR', 11, 43260.0, 166.55783],
#  ['6091_02', '17:44:00', 'os.Górczewska', 'TP-GOR', 11, 43380.0, 167.10751],
#  ['6093_02', '17:45:00', 'os.Górczewska', 'TP-GOR', 11, 43440.0, 167.41365],
#  ['6129_02', '17:47:00', 'os.Górczewska', 'TP-GOR', 11, 43560.0, 167.78153],
#  ['6155_03', '17:49:00', 'os.Górczewska', 'TP-GOR', 11, 43680.0, 168.36203],
#  ['6131_02', '17:51:00', 'os.Górczewska', 'TP-GOR', 11, 43800.0, 168.6479],
#  ['6132_02', '17:52:00', 'os.Górczewska', 'TP-GOR', 11, 43860.0, 169.05334],
#  ['6047_01', '17:54:00', 'os.Górczewska', 'TP-GOR', 11, 43980.0, 169.52384],
#  ['5065_02', '17:55:00', 'os.Górczewska', 'TP-GOR', 11, 44040.0, 169.82566],
#  ['5062_03', '17:57:00', 'os.Górczewska', 'TP-GOR', 11, 44160.0, 170.41041],
#  ['5102_02', '17:59:00', 'os.Górczewska', 'TP-GOR', 11, 44280.0, 171.02855],
#  ['5064_04', '18:01:00', 'os.Górczewska', 'TP-GOR', 11, 44400.0, 171.67862],
#  ['5107_02', '18:02:00', 'os.Górczewska', 'TP-GOR', 11, 44460.0, 172.06846],
#  ['5106_02', '18:04:00', 'os.Górczewska', 'TP-GOR', 11, 44580.0, 172.61874],
#  ['5063_04', '18:06:00', 'os.Górczewska', 'TP-GOR', 11, 44700.0, 173.23248],
#  ['5110_02', '18:07:00', 'os.Górczewska', 'TP-GOR', 11, 44760.0, 173.75794],
#  ['5055_01', '18:09:00', 'os.Górczewska', 'TP-GOR', 11, 44880.0, 174.40602],
#  ['5054_01', '18:10:00', 'os.Górczewska', 'TP-GOR', 11, 44940.0, 174.7612],
#  ['5053_01', '18:11:00', 'os.Górczewska', 'TP-GOR', 11, 45000.0, 175.21787],
#  ['5163_01', '18:12:00', 'os.Górczewska', 'TP-GOR', 11, 45060.0, 175.5239],
#  ['5052_01', '18:14:00', 'os.Górczewska', 'TP-GOR', 11, 45180.0, 175.84918],
#  ['5051_01', '18:15:00', 'os.Górczewska', 'TP-GOR', 11, 45240.0, 176.35874],
#  ['5050_03', '18:17:00', 'os.Górczewska', 'TP-GOR', 11, 45360.0, 176.57838],
#  ['5050_08', '18:29:00', 'Gwiaździsta', 'TP-GWI', 12, 46080.0, 176.70376],
#  ['5050_02', '18:30:00', 'Gwiaździsta', 'TP-GWI', 12, 46140.0, 176.93636],
#  ['5051_02', '18:32:00', 'Gwiaździsta', 'TP-GWI', 12, 46260.0, 177.2169],
#  ['5052_02', '18:34:00', 'Gwiaździsta', 'TP-GWI', 12, 46380.0, 177.78464],
#  ['5163_02', '18:35:00', 'Gwiaździsta', 'TP-GWI', 12, 46440.0, 178.0046],
#  ['5053_02', '18:36:00', 'Gwiaździsta', 'TP-GWI', 12, 46500.0, 178.32374],
#  ['5054_02', '18:37:00', 'Gwiaździsta', 'TP-GWI', 12, 46560.0, 178.71727],
#  ['5055_07', '18:38:00', 'Gwiaździsta', 'TP-GWI', 12, 46620.0, 178.95307],
#  ['5110_01', '18:39:00', 'Gwiaździsta', 'TP-GWI', 12, 46680.0, 179.47035],
#  ['5063_03', '18:41:00', 'Gwiaździsta', 'TP-GWI', 12, 46800.0, 180.19244],
#  ['5106_01', '18:43:00', 'Gwiaździsta', 'TP-GWI', 12, 46920.0, 180.72138],
#  ['5107_01', '18:44:00', 'Gwiaździsta', 'TP-GWI', 12, 46980.0, 181.13161],
#  ['5064_07', '18:46:00', 'Gwiaździsta', 'TP-GWI', 12, 47100.0, 181.7888],
#  ['5102_01', '18:48:00', 'Gwiaździsta', 'TP-GWI', 12, 47220.0, 182.38111],
#  ['5062_01', '18:50:00', 'Gwiaździsta', 'TP-GWI', 12, 47340.0, 183.05782],
#  ['5065_01', '18:52:00', 'Gwiaździsta', 'TP-GWI', 12, 47460.0, 183.7039],
#  ['6047_03', '18:53:00', 'Gwiaździsta', 'TP-GWI', 12, 47520.0, 183.93992],
#  ['6132_01', '18:55:00', 'Gwiaździsta', 'TP-GWI', 12, 47640.0, 184.54105],
#  ['6131_01', '18:56:00', 'Gwiaździsta', 'TP-GWI', 12, 47700.0, 184.86773],
#  ['6155_01', '18:58:00', 'Gwiaździsta', 'TP-GWI', 12, 47820.0, 185.1311],
#  ['6129_01', '19:00:00', 'Gwiaździsta', 'TP-GWI', 12, 47940.0, 185.84134],
#  ['6093_01', '19:01:00', 'Gwiaździsta', 'TP-GWI', 12, 48000.0, 186.12688],
#  ['6091_04', '19:02:00', 'Gwiaździsta', 'TP-GWI', 12, 48060.0, 186.44759],
#  ['6088_01', '19:03:00', 'Gwiaździsta', 'TP-GWI', 12, 48120.0, 186.94482],
#  ['6040_05', '19:05:00', 'Gwiaździsta', 'TP-GWI', 12, 48240.0, 187.36449],
#  ['6094_05', '19:06:00', 'Gwiaździsta', 'TP-GWI', 12, 48300.0, 187.6576],
#  ['6098_01', '19:07:00', 'Gwiaździsta', 'TP-GWI', 12, 48360.0, 187.93932],
#  ['6003_09', '19:09:00', 'Gwiaździsta', 'TP-GWI', 12, 48480.0, 188.3784],
#  ['6003_04', '19:11:00', 'Gwiaździsta', 'TP-GWI', 12, 48600.0, 188.54263],
#  ['6076_02', '19:12:00', 'Gwiaździsta', 'TP-GWI', 12, 48660.0, 188.91388],
#  ['6078_02', '19:13:00', 'Gwiaździsta', 'TP-GWI', 12, 48720.0, 189.31283],
#  ['6079_02', '19:15:00', 'Gwiaździsta', 'TP-GWI', 12, 48840.0, 189.70269],
#  ['6080_02', '19:16:00', 'Gwiaździsta', 'TP-GWI', 12, 48900.0, 190.07206],
#  ['6082_02', '19:17:00', 'Gwiaździsta', 'TP-GWI', 12, 48960.0, 190.87277],
#  ['6081_02', '19:17:00', 'Gwiaździsta', 'TP-GWI', 12, 48960.0, 191.16184],
#  ['6082_06', '19:40:00', 'os.Górczewska', 'TP-GOR', 13, 50340.0, 191.65245],
#  ['6082_01', '19:41:00', 'os.Górczewska', 'TP-GOR', 13, 50400.0, 192.01302],
#  ['6081_01', '19:41:00', 'os.Górczewska', 'TP-GOR', 13, 50400.0, 192.24371],
#  ['6080_01', '19:42:00', 'os.Górczewska', 'TP-GOR', 13, 50460.0, 192.77315],
#  ['6079_01', '19:43:00', 'os.Górczewska', 'TP-GOR', 13, 50520.0, 193.14724],
#  ['6078_01', '19:44:00', 'os.Górczewska', 'TP-GOR', 13, 50580.0, 193.51195],
#  ['6077_01', '19:45:00', 'os.Górczewska', 'TP-GOR', 13, 50640.0, 193.69823],
#  ['6076_01', '19:46:00', 'os.Górczewska', 'TP-GOR', 13, 50700.0, 193.93293],
#  ['6003_03', '19:47:00', 'os.Górczewska', 'TP-GOR', 13, 50760.0, 194.29773],
#  ['6003_06', '19:49:00', 'os.Górczewska', 'TP-GOR', 13, 50880.0, 194.43585],
#  ['6098_02', '19:50:00', 'os.Górczewska', 'TP-GOR', 13, 50940.0, 194.68613],
#  ['6094_06', '19:51:00', 'os.Górczewska', 'TP-GOR', 13, 51000.0, 195.13967],
#  ['6040_06', '19:53:00', 'os.Górczewska', 'TP-GOR', 13, 51120.0, 195.51521],
#  ['6088_02', '19:54:00', 'os.Górczewska', 'TP-GOR', 13, 51180.0, 195.84644],
#  ['6091_02', '19:55:00', 'os.Górczewska', 'TP-GOR', 13, 51240.0, 196.39612],
#  ['6093_02', '19:56:00', 'os.Górczewska', 'TP-GOR', 13, 51300.0, 196.70226],
#  ['6129_02', '19:57:00', 'os.Górczewska', 'TP-GOR', 13, 51360.0, 197.07014],
#  ['6155_03', '19:58:00', 'os.Górczewska', 'TP-GOR', 13, 51420.0, 197.65064],
#  ['6131_02', '20:00:00', 'os.Górczewska', 'TP-GOR', 13, 51540.0, 197.93651],
#  ['6132_02', '20:01:00', 'os.Górczewska', 'TP-GOR', 13, 51600.0, 198.34195],
#  ['6047_01', '20:03:00', 'os.Górczewska', 'TP-GOR', 13, 51720.0, 198.81245],
#  ['5065_02', '20:04:00', 'os.Górczewska', 'TP-GOR', 13, 51780.0, 199.11427],
#  ['5062_03', '20:06:00', 'os.Górczewska', 'TP-GOR', 13, 51900.0, 199.69902],
#  ['5102_02', '20:08:00', 'os.Górczewska', 'TP-GOR', 13, 52020.0, 200.31716],
#  ['5064_04', '20:10:00', 'os.Górczewska', 'TP-GOR', 13, 52140.0, 200.96723],
#  ['5107_02', '20:11:00', 'os.Górczewska', 'TP-GOR', 13, 52200.0, 201.35707],
#  ['5106_02', '20:13:00', 'os.Górczewska', 'TP-GOR', 13, 52320.0, 201.90735],
#  ['5063_04', '20:15:00', 'os.Górczewska', 'TP-GOR', 13, 52440.0, 202.52109],
#  ['5110_02', '20:16:00', 'os.Górczewska', 'TP-GOR', 13, 52500.0, 203.04655],
#  ['5055_01', '20:17:00', 'os.Górczewska', 'TP-GOR', 13, 52560.0, 203.69463],
#  ['5054_01', '20:18:00', 'os.Górczewska', 'TP-GOR', 13, 52620.0, 204.04981],
#  ['5053_01', '20:19:00', 'os.Górczewska', 'TP-GOR', 13, 52680.0, 204.50648],
#  ['5163_01', '20:20:00', 'os.Górczewska', 'TP-GOR', 13, 52740.0, 204.81251],
#  ['5052_01', '20:21:00', 'os.Górczewska', 'TP-GOR', 13, 52800.0, 205.13779],
#  ['5051_01', '20:22:00', 'os.Górczewska', 'TP-GOR', 13, 52860.0, 205.64735],
#  ['5050_03', '20:24:00', 'os.Górczewska', 'TP-GOR', 13, 52980.0, 205.86699],
#  ['5050_08', '20:42:00', 'Gwiaździsta', 'TP-GWI', 14, 54060.0, 205.99237],
#  ['5050_02', '20:43:00', 'Gwiaździsta', 'TP-GWI', 14, 54120.0, 206.22497],
#  ['5051_02', '20:44:00', 'Gwiaździsta', 'TP-GWI', 14, 54180.0, 206.50551],
#  ['5052_02', '20:45:00', 'Gwiaździsta', 'TP-GWI', 14, 54240.0, 207.07325],
#  ['5163_02', '20:46:00', 'Gwiaździsta', 'TP-GWI', 14, 54300.0, 207.29321],
#  ['5053_02', '20:47:00', 'Gwiaździsta', 'TP-GWI', 14, 54360.0, 207.61235],
#  ['5054_02', '20:48:00', 'Gwiaździsta', 'TP-GWI', 14, 54420.0, 208.00588],
#  ['5055_07', '20:49:00', 'Gwiaździsta', 'TP-GWI', 14, 54480.0, 208.24168],
#  ['5110_01', '20:50:00', 'Gwiaździsta', 'TP-GWI', 14, 54540.0, 208.75896],
#  ['5063_03', '20:52:00', 'Gwiaździsta', 'TP-GWI', 14, 54660.0, 209.48105],
#  ['5106_01', '20:54:00', 'Gwiaździsta', 'TP-GWI', 14, 54780.0, 210.00999],
#  ['5107_01', '20:55:00', 'Gwiaździsta', 'TP-GWI', 14, 54840.0, 210.42022],
#  ['5064_07', '20:57:00', 'Gwiaździsta', 'TP-GWI', 14, 54960.0, 211.07741],
#  ['5102_01', '20:58:00', 'Gwiaździsta', 'TP-GWI', 14, 55020.0, 211.66972],
#  ['5062_01', '21:00:00', 'Gwiaździsta', 'TP-GWI', 14, 55140.0, 212.34643],
#  ['5065_01', '21:01:00', 'Gwiaździsta', 'TP-GWI', 14, 55200.0, 212.99251],
#  ['6047_03', '21:02:00', 'Gwiaździsta', 'TP-GWI', 14, 55260.0, 213.22853],
#  ['6132_01', '21:04:00', 'Gwiaździsta', 'TP-GWI', 14, 55380.0, 213.82966],
#  ['6131_01', '21:05:00', 'Gwiaździsta', 'TP-GWI', 14, 55440.0, 214.15634],
#  ['6155_01', '21:06:00', 'Gwiaździsta', 'TP-GWI', 14, 55500.0, 214.41971],
#  ['6129_01', '21:08:00', 'Gwiaździsta', 'TP-GWI', 14, 55620.0, 215.12995],
#  ['6093_01', '21:09:00', 'Gwiaździsta', 'TP-GWI', 14, 55680.0, 215.41549],
#  ['6091_04', '21:10:00', 'Gwiaździsta', 'TP-GWI', 14, 55740.0, 215.7362],
#  ['6088_01', '21:11:00', 'Gwiaździsta', 'TP-GWI', 14, 55800.0, 216.23343],
#  ['6040_05', '21:12:00', 'Gwiaździsta', 'TP-GWI', 14, 55860.0, 216.6531],
#  ['6094_05', '21:13:00', 'Gwiaździsta', 'TP-GWI', 14, 55920.0, 216.94621],
#  ['6098_01', '21:14:00', 'Gwiaździsta', 'TP-GWI', 14, 55980.0, 217.22793],
#  ['6003_09', '21:16:00', 'Gwiaździsta', 'TP-GWI', 14, 56100.0, 217.66701],
#  ['6003_04', '21:18:00', 'Gwiaździsta', 'TP-GWI', 14, 56220.0, 217.83124],
#  ['6076_02', '21:19:00', 'Gwiaździsta', 'TP-GWI', 14, 56280.0, 218.20249],
#  ['6078_02', '21:20:00', 'Gwiaździsta', 'TP-GWI', 14, 56340.0, 218.60144],
#  ['6079_02', '21:22:00', 'Gwiaździsta', 'TP-GWI', 14, 56460.0, 218.9913],
#  ['6080_02', '21:23:00', 'Gwiaździsta', 'TP-GWI', 14, 56520.0, 219.36067],
#  ['6082_02', '21:24:00', 'Gwiaździsta', 'TP-GWI', 14, 56580.0, 220.16138],
#  ['6081_02', '21:24:00', 'Gwiaździsta', 'TP-GWI', 14, 56580.0, 220.45045],
#  ['6082_06', '21:41:00', 'os.Górczewska', 'TP-GOR', 15, 57600.0, 220.94106],
#  ['6081_01', '21:42:00', 'os.Górczewska', 'TP-GOR', 15, 57660.0, 221.52476],
#  ['6082_01', '21:42:00', 'os.Górczewska', 'TP-GOR', 15, 57660.0, 221.75545],
#  ['6080_01', '21:43:00', 'os.Górczewska', 'TP-GOR', 15, 57720.0, 222.51032],
#  ['6079_01', '21:44:00', 'os.Górczewska', 'TP-GOR', 15, 57780.0, 222.88441],
#  ['6078_01', '21:45:00', 'os.Górczewska', 'TP-GOR', 15, 57840.0, 223.24912],
#  ['6077_01', '21:46:00', 'os.Górczewska', 'TP-GOR', 15, 57900.0, 223.4354],
#  ['6076_01', '21:47:00', 'os.Górczewska', 'TP-GOR', 15, 57960.0, 223.6701],
#  ['6003_03', '21:48:00', 'os.Górczewska', 'TP-GOR', 15, 58020.0, 224.0349],
#  ['6003_06', '21:49:00', 'os.Górczewska', 'TP-GOR', 15, 58080.0, 224.17302],
#  ['6098_02', '21:50:00', 'os.Górczewska', 'TP-GOR', 15, 58140.0, 224.4233],
#  ['6094_06', '21:51:00', 'os.Górczewska', 'TP-GOR', 15, 58200.0, 224.87684],
#  ['6040_06', '21:53:00', 'os.Górczewska', 'TP-GOR', 15, 58320.0, 225.25238],
#  ['6088_02', '21:54:00', 'os.Górczewska', 'TP-GOR', 15, 58380.0, 225.58361],
#  ['6091_02', '21:55:00', 'os.Górczewska', 'TP-GOR', 15, 58440.0, 226.13329],
#  ['6093_02', '21:56:00', 'os.Górczewska', 'TP-GOR', 15, 58500.0, 226.43943],
#  ['6129_02', '21:57:00', 'os.Górczewska', 'TP-GOR', 15, 58560.0, 226.80731],
#  ['6155_03', '21:58:00', 'os.Górczewska', 'TP-GOR', 15, 58620.0, 227.38781],
#  ['6131_02', '22:00:00', 'os.Górczewska', 'TP-GOR', 15, 58740.0, 227.67368],
#  ['6132_02', '22:01:00', 'os.Górczewska', 'TP-GOR', 15, 58800.0, 228.07912],
#  ['6047_01', '22:03:00', 'os.Górczewska', 'TP-GOR', 15, 58920.0, 228.54962],
#  ['5065_02', '22:04:00', 'os.Górczewska', 'TP-GOR', 15, 58980.0, 228.85144],
#  ['5062_03', '22:06:00', 'os.Górczewska', 'TP-GOR', 15, 59100.0, 229.43619],
#  ['5102_02', '22:07:00', 'os.Górczewska', 'TP-GOR', 15, 59160.0, 230.05433],
#  ['5064_04', '22:09:00', 'os.Górczewska', 'TP-GOR', 15, 59280.0, 230.7044],
#  ['5107_02', '22:10:00', 'os.Górczewska', 'TP-GOR', 15, 59340.0, 231.09424],
#  ['5106_02', '22:12:00', 'os.Górczewska', 'TP-GOR', 15, 59460.0, 231.64452],
#  ['5063_04', '22:14:00', 'os.Górczewska', 'TP-GOR', 15, 59580.0, 232.25826],
#  ['5110_02', '22:15:00', 'os.Górczewska', 'TP-GOR', 15, 59640.0, 232.78372],
#  ['5055_01', '22:16:00', 'os.Górczewska', 'TP-GOR', 15, 59700.0, 233.4318],
#  ['5054_01', '22:17:00', 'os.Górczewska', 'TP-GOR', 15, 59760.0, 233.78698],
#  ['5053_01', '22:18:00', 'os.Górczewska', 'TP-GOR', 15, 59820.0, 234.24365],
#  ['5163_01', '22:19:00', 'os.Górczewska', 'TP-GOR', 15, 59880.0, 234.54968],
#  ['5052_01', '22:20:00', 'os.Górczewska', 'TP-GOR', 15, 59940.0, 234.87496],
#  ['5051_01', '22:21:00', 'os.Górczewska', 'TP-GOR', 15, 60000.0, 235.38452],
#  ['5050_03', '22:23:00', 'os.Górczewska', 'TP-GOR', 15, 60120.0, 235.60416]]

# %%
def filter_gps(list_od_tuples, x_limits, y_limits):
    return [x for x in list_od_tuples if coord_check(x, x_limits, y_limits)] # (20.0, 22.0), (51.0, 53.0)
#     return list(filter(lambda x: coord_check(x, x_limits, y_limits), list_od_tuples))                    # faster?

def coord_check(to_check, x_limits, y_limits):
    x, y = to_check
    x_min, x_max = x_limits
    y_min, y_max = y_limits
    if((x_min < x < x_max) & (y_min < y < y_max)):
        return True
    else:
        return False
    
def flip(coords):
    return [(y, x) for x, y in coords]   # [x[::-1] for x in coords]

def simplify_to_nr(path, nr, tolerance=0, func=simplify_coords, max_iter=100): # simplify_coords_vw
    range_l = 0.0
    range_h = 1.0
    iteration = 1
    while True:
        param = (range_l + range_h)/2
        result = func(path, param)
        result_len = len(result)
        if((result_len >= nr-tolerance) & (result_len <= nr+tolerance)):
            print('Iteration: ', iteration, '      Number: ', result_len, ' Parameter: ', param)
            return result
        elif (result_len < nr): # parameter to high
            range_h = param
            iteration += 1
        else:                      # parameter to low
            range_l = param
            iteration += 1
        if(iteration > max_iter):
            print('calculation to long, Number: ', result_len, ' Parameter: ', param)
            return result  

def draw_simpl_path(line, brig_idx, nr_points, tolerance=0, rdp=True, wv=True):
    brigades = GPS_df[GPS_df.Lines.isin(['122'])].Brigade.value_counts().keys().tolist()
    print(line, brigades)
    line_stops = stops_coords_list([line])
    route = GPS_df[GPS_df.Lines.isin([line]) & 
                   GPS_df.Brigade.isin([brigades[brig_idx]])].sort_values(['Time'])[['Lon', 'Lat']].values
    route = filter_gps(route, (20.0, 22.0), (51.0, 53.0))
    route = np.ascontiguousarray(route)
    simpl_rdp = simplify_to_nr(route, nr_points)
    simpl_vw = simplify_to_nr(route, nr_points, tolerance, func=simplify_coords_vw)
    print(len(line_stops), route.shape, simpl_rdp.shape, simpl_vw.shape)
    print('stops ', path_dist(line_stops), 
          ' gps ', path_dist(route), 
          ' rdp ', path_dist(simpl_rdp), 
          ' wv', path_dist(simpl_vw))
    plt.figure(figsize=(10,6))
    plt.scatter(*zip(*route))
    if(rdp):
        plt.scatter(*zip(*simpl_rdp))
    if(wv):
        plt.scatter(*zip(*simpl_vw))
    plt.show()

    def path_dist(to_check_distance):
    sumed = 0.0
    last_first, last_second = to_check_distance[0]
    for first, second in to_check_distance:
        dist = round(geopy.distance.distance((last_second, last_first), (second, first)).kilometers, 5)
        sumed += dist
        last_first, last_second = first, second
    return sumed

def stops_coords_list(line):
    a = lines_df[lines_df.line_nr.isin(line)]['stops'].values[0]
    b = [stop_coords[x] for x in a]
    b = flip(b)          
    b = filter_gps(b, (20.0, 22.0), (51.0, 53.0))
    return b

def draw_stops(b):         
    #b = stops_coords_list(line)
    print('stops nr: ', len(b))
    plt.figure(figsize=(10,6))
    plt.scatter(*zip(*b));

# %% [markdown]
# ### Ramer–Douglas–Peucker or Visvalingam-Whyatt algorithms

# %%
print(GPS_df.shape)
with open('GPS_df.pickle', 'rb') as fp:
    GPS_df = pickle.load(fp)
GPS_df.shape
# Out:
# (1160129, 13)
# (1136854, 18)

# %%
with open('stops_dist_dict.pickle', 'rb') as fp:
    stops_dist_dict = pickle.load(fp)

# %%
len(stops_dist_dict)         # odległości w lini prostej między kolejnymi przystankami - wyszukiwanie w słowniku jest szybsze niż obliczanie z geopy, klucz: wartość -> ('6074_02', '6073_02'): 0.42795
# Out:
# 10718
